# %% [raw]
# [作業1]
#  仿造範例的MAE函數, 自己寫一個MSE函數

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 253.522
# The Mean absolute error is 13.469

# %% [raw]
# [作業2]
# Goodreads-books (comprehensive list of all books listed in goodreads)
# <Ref> https://www.kaggle.com/jealousleopard/goodreadsbooks
# 1. This data help people find out what book you should be reading next.
# 2. This data was entirely scraped via the Goodreads API.
#    Goodreads API:https://www.goodreads.com/api
# 3. bookID:ID, title:string, authors:string, average_rating:decimal, isbn:string, isbn13:int,
#    language_code:string, #num_pages:int, #ratings_count:int, #text_reviews_count:int
# 4. First, remove the book which #ratings_count is low. Then, find the relevance between each column repeatedly.
#
# [作業3]
# 1. Use the transaction data in the past to improve performance and set different mileage billing depending on supply and demand. My assumption: Customers are willing to pay extra fee in the rush hour; on the contrary, the relatively lower price in the off-peak will motivate them to take a taxi.
# 2. Transaction in the past
# 3. transactionID:ID, time(min):int, distance:decimal, weather_rating:decimal, #empty_car:int
# 4. Use the past transaction to set a new mileage billing rate. After carry out the new floating price policy for two weeks, collect the transaction data and analyze the result.
